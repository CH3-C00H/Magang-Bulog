# %% [markdown]
# #IMPORT PACKAGE

# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.pyplot import axes

# %% [markdown]
# #DATA CLEANING

# %%
df = pd.read_excel("/content/UNS 2018.xlsx")
df.to_csv("/content/uns_2018.csv")
pd2018 = pd.read_csv("/content/uns_2018.csv")
##############
df = pd.read_excel("/content/UNS 2019.xlsx")
df.to_csv("/content/uns_2019.csv")
pd2019 = pd.read_csv("/content/uns_2019.csv")
##############
df = pd.read_excel("/content/UNS 2020.xlsx")
df.to_csv("/content/uns_2020.csv")
pd2020 = pd.read_csv("/content/uns_2020.csv")
##############
df = pd.read_excel("/content/UNS 2021.xlsx")
df.to_csv("/content/uns_2021.csv")
pd2021 = pd.read_csv("/content/uns_2021.csv")

# %%
df2018 = pd2018.rename(columns={"Saluran (Kategori RKAP)":"Saluran_Kategori_RKAP","Nama Pembeli":"Nama_Pembeli","Nama Komoditi":"Nama_Komoditi","Jenis Komoditi":"Jenis_Komoditi","Merk Komoditi":"Merk_Komoditi"
,"Kolli DO":"Koli_DO","Kuantum DO (Kg/L)":"Kuantum_DO","Kolli Terjual":"Koli_Terjual","Kuantum Terjual (Kg/L)":"Kuantum_Terjual"}) #Rename
df2018 = df2018.drop("Unnamed: 0",axis=1) #Remove kolom yang tidak terpakai
Kemasan_fix = df2018["Kemasan"].str.replace(',','.').astype(float) #ubah notasi   
df2018["Kemasan"] = Kemasan_fix #masukin ke dataframe
df2018["Tanggal"] = pd.to_datetime(df2018["Tanggal"],format="%d-%m-%Y")
df2018["Hari"] = df2018["Tanggal"].dt.strftime("%A")
df2018["Bulan"]= df2018["Tanggal"].dt.strftime("%B")

# %%
df2019 = pd2019.rename(columns={"Saluran (Kategori RKAP)":"Saluran_Kategori_RKAP","Nama Pembeli":"Nama_Pembeli","Nama Komoditi":"Nama_Komoditi","Jenis Komoditi":"Jenis_Komoditi","Merk Komoditi":"Merk_Komoditi"
,"Kolli DO":"Koli_DO","Kuantum DO (Kg/L)":"Kuantum_DO","Kolli Terjual":"Koli_Terjual","Kuantum Terjual (Kg/L)":"Kuantum_Terjual"}) #Rename
df2019 = df2019.drop("Unnamed: 0",axis=1) #Remove kolom yang tidak terpakai
Kemasan_fix = df2019["Kemasan"].str.replace(',','.').astype(float) #ubah notasi   
df2019["Kemasan"] = Kemasan_fix #masukin ke dataframe
df2019 ["Tanggal"] = pd.to_datetime(df2019["Tanggal"],format="%d-%m-%Y")
df2019["Bulan"] = df2019["Tanggal"].dt.strftime("%B")
df2019["Hari"]= df2019["Tanggal"].dt.strftime("%A")

# %%
df2020 = pd2020.rename(columns={"Saluran (Kategori RKAP)":"Saluran_Kategori_RKAP","Nama Pembeli":"Nama_Pembeli","Nama Komoditi":"Nama_Komoditi","Jenis Komoditi":"Jenis_Komoditi","Merk Komoditi":"Merk_Komoditi"
,"Kolli DO":"Koli_DO","Kuantum DO (Kg/L)":"Kuantum_DO","Kolli Terjual":"Koli_Terjual","Kuantum Terjual (Kg/L)":"Kuantum_Terjual"}) #Rename
df2020 = df2020.drop("Unnamed: 0",axis=1) #Remove kolom yang tidak terpakai
Kemasan_fix = df2020["Kemasan"].str.replace(',','.').astype(float) #ubah notasi   
df2020["Kemasan"] = Kemasan_fix #masukin ke dataframe
df2020["Tanggal"] = pd.to_datetime(df2020["Tanggal"],format="%d-%m-%Y")
df2020["Bulan"] = df2020["Tanggal"].dt.strftime("%B")
df2020["Hari"]= df2020["Tanggal"].dt.strftime("%A")

# %%
df2021 = pd2021.rename(columns={"Saluran (Kategori RKAP)":"Saluran_Kategori_RKAP","Nama Pembeli":"Nama_Pembeli","Nama Komoditi":"Nama_Komoditi","Jenis Komoditi":"Jenis_Komoditi","Merk Komoditi":"Merk_Komoditi"
,"Kolli DO":"Koli_DO","Kuantum DO (Kg/L)":"Kuantum_DO","Kolli Terjual":"Koli_Terjual","Kuantum Terjual (Kg/L)":"Kuantum_Terjual"}) #Rename
df2021 = df2021.drop("Unnamed: 0",axis=1) #Remove kolom yang tidak terpakai
Kemasan_fix = df2021["Kemasan"].str.replace(',','.').astype(float) #ubah notasi   
df2021["Kemasan"] = Kemasan_fix #masukin ke dataframe
df2021 ["Tanggal"] = pd.to_datetime(df2021["Tanggal"],format="%d-%m-%Y")
df2021["Bulan"] = df2021["Tanggal"].dt.strftime("%B")
df2021["Hari"]= df2021["Tanggal"].dt.strftime("%A")

# %% [markdown]
# #VISUALISASI (KOMODITI YTD)

# %%
c = []
d = []
a = df2018["Nama_Komoditi"].unique()
for i in a :
  a = df2018.loc[df2018.Nama_Komoditi == i]
  b = len(a)
  d.append(i)
  c.append(b)
fig1, ax1 = plt.subplots()
plt.rcParams['figure.figsize'] = (20, 10)
ax1.bar(x=d,height = c,width=0.2)
plt.grid()
plt.title("Komoditi 2018",{'fontsize': 20})
plt.show()

# %%
c = []
d = []
a = df2019["Nama_Komoditi"].unique()
for i in a :
  a = df2019.loc[df2019.Nama_Komoditi == i]
  b = len(a)
  d.append(i)
  c.append(b)
fig1, ax1 = plt.subplots()
plt.rcParams['figure.figsize'] = (20, 10)
ax1.bar(x=d,height = c,width=0.2)
plt.grid()
plt.title("Komoditi 2019",{'fontsize': 20})
plt.show()

# %%
c = []
d = []
a = df2020["Nama_Komoditi"].unique()
for i in a :
  a = df2020.loc[df2020.Nama_Komoditi == i]
  b = len(a)
  d.append(i)
  c.append(b)
fig1, ax1 = plt.subplots()
plt.rcParams['figure.figsize'] = (26, 10)
ax1.bar(x=d,height = c,width=0.2)
plt.grid()
plt.title("Komoditi 2020",{'fontsize': 20})
plt.show()

# %%
c = []
d = []
a = df2021["Nama_Komoditi"].unique()
for i in a :
  a = df2021.loc[df2021.Nama_Komoditi == i]
  b = len(a)
  d.append(i)
  c.append(b)
fig1, ax1 = plt.subplots()
plt.rcParams['figure.figsize'] = (26, 10)
ax1.bar(x=d,height = c,width=0.2)
plt.grid()
plt.title("Komoditi 2021",{'fontsize': 20})
plt.show()

# %% [markdown]
# #ANALISA BERAS

# %%
e = (df2018.loc[(df2018.Nama_Komoditi == "BERAS")])
f = (df2019.loc[(df2019.Nama_Komoditi == "BERAS")])
g = (df2020.loc[(df2020.Nama_Komoditi == "BERAS")])
h = (df2021.loc[(df2021.Nama_Komoditi == "BERAS")])
I = (df2018.loc[(df2018.Nama_Komoditi == "BERAS")&((df2018.Saluran == "RPK"))])
J = (df2019.loc[(df2019.Nama_Komoditi == "BERAS")&((df2019.Saluran == "RPK"))])
K = (df2020.loc[(df2020.Nama_Komoditi == "BERAS")&((df2020.Saluran == "RPK"))])
L = (df2021.loc[(df2021.Nama_Komoditi == "BERAS")&((df2021.Saluran == "RPK"))])

# %%
eee = e["Kuantum_DO"]
fff = f["Kuantum_DO"]
ggg = g["Kuantum_DO"]
hhh = h["Kuantum_DO"]
listlist = [eee,fff,ggg,hhh]
indeks_tahun = 18
sum_i = []
for i in listlist:
  print("Total Beras pada tahun 20"+str(indeks_tahun)+" adalah = "+str(sum(i))+" Kg")
  indeks_tahun +=1
  sum_i.append(sum(i))
print("\n")
cc = ["Tahun 2018","Beras 2019","Beras 2020","Beras 2021"]
fig1, ax1 = plt.subplots()
plt.rcParams['figure.figsize'] = (20, 10)
ax1.bar(x=cc,height = sum_i,width=0.2)
plt.yscale("log")
plt.plot(cc,sum_i)
plt.title("Banyaknya Beras yang Beredar(2018-2021)",{'fontsize': 20})
plt.grid(axis = "both",which= 'minor')
plt.ylabel("Dalam Kg",{"fontsize" : 15})
plt.show()
# Out:
# Total Beras pada tahun 2018 adalah = 2210985.999999999 Kg
# Total Beras pada tahun 2019 adalah = 4419868.8 Kg
# Total Beras pada tahun 2020 adalah = 5022967.2499999935 Kg
# Total Beras pada tahun 2021 adalah = 1305448.15 Kg

# %%
aa = [len(e),len(f),len(g),len(h)]
cc = ["Beras 2018","Beras 2019","Beras 2020","Beras 2021"]

fig1, ax1 = plt.subplots()
plt.rcParams['figure.figsize'] = (20, 10)
ax1.bar(x=cc,height = aa,width=0.2)
plt.grid(axis = "y")
plt.title("Frekuensi Beras yang Beredar (2018 - 2021)",{'fontsize': 20})
plt.show()

# %%
II = I["Kuantum_DO"]
JJ = J["Kuantum_DO"]
KK = K["Kuantum_DO"]
LL = L["Kuantum_DO"]
listlist = [II,JJ,KK,LL]
indeks_tahun = 18
sum_i = []
for i in listlist:
  print("Total Beras pada tahun 20"+str(indeks_tahun)+" adalah = "+str(sum(i))+" Kg")
  indeks_tahun +=1
  sum_i.append(sum(i))
print("\n")
cc = ["Tahun 2018","Beras 2019","Beras 2020","Beras 2021"]
fig1, ax1 = plt.subplots()
plt.rcParams['figure.figsize'] = (20, 10)
ax1.bar(x=cc,height = sum_i,width=0.2)
plt.yscale("log")
plt.plot(cc,sum_i)
plt.title("Banyaknya Beras yang Beredar terhadap RKP(2018-2021)",{'fontsize': 20})
plt.grid(axis = "both",which= 'minor')
plt.ylabel("Dalam Kg",{"fontsize" : 15})
plt.show()
# Out:
# Total Beras pada tahun 2018 adalah = 1832104.2999999993 Kg
# Total Beras pada tahun 2019 adalah = 3365682.299999999 Kg
# Total Beras pada tahun 2020 adalah = 3799514.2500000033 Kg
# Total Beras pada tahun 2021 adalah = 911992.1499999999 Kg

# %% [markdown]
# ## BERAS YANG TERDISTRIBUSI DI SURAKARTA

# %%
vm = df2019["Nama_Pembeli"].unique().tolist()
xc = []
for i in vm :
  if "SOLO" in i:
    xc.append(i)
  elif "Solo" in i:
    xc.append(i)
  elif "Surakarta" in i:
    xc.append(i)
for i in xc :
  aa = (df2019.loc[(df2019.Nama_Komoditi == "BERAS") +(df2019.Nama_Pembeli == i)])
VM = df2019[df2019.Nama_Pembeli.isin(xc)]
print("Total beras yang terdistribusi di wilayah Surakarta adalah " + str(sum(VM["Kuantum_Terjual"]))+" Kg")
print("Pembeli yang berasal dari Solo sebagai berikut:\n",xc)
# Out:
# Total beras yang terdistribusi di wilayah Surakarta adalah 18367.0 Kg
# Pembeli yang berasal dari Solo sebagai berikut:
#  ['Hotel Megaland Surakarta', 'Depo Solo', 'MITRA SOLO', 'RPK BERKAH SOLO', 'RPK Primkop Kartika D-02 Warastratama (Kodim D-02 Surakarta)', 'RPK Primkop Kartika D-01 Warastratama (Korem D-01 Surakarta)', 'TPK Pasar Harjodaksino Surakarta Ade Irawan', 'Koperasi Bank Bukopin KCU Solo', 'RS JIH SOLO', 'PT. Asuransi Jasindo (persero) KC Solo', 'RPK POLRESTA SOLO', 'Solo Bistro', 'Hotel Syariah Solo', 'TPK Pasar Nusukan Surakarta Sri Supeni', 'Ayam Geprek Abang Ireng Outlet ISI (Kantor Pusat Solo)', 'TPK Pasar Rejosari Surakarta Ngadimin', 'Hotel lampion Surakarta', 'PT. Taspen Cabang Surakarta']
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py:204: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   f"evaluating in Python space because the {repr(op_str)} "

# %% [markdown]
# ## JUMLAH BERAS PER BULAN

# %%
beras2018b = e.groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
beras2019b = f.groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
beras2020b = g.groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
beras2021b = h.groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
fig, axs = plt.subplots(2, 2)
axs[0,0].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[0,1].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[1,0].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[1,1].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[0, 0].bar(x=beras2018b.index,height=beras2018b['Kuantum_Terjual'],width=0.2)
axs[0, 0].set_title(label="Distribusi beras (2018)",fontdict={"fontsize":25})
axs[0, 0].grid(True)
axs[0, 1].bar(x=beras2019b.index,height=beras2019b['Kuantum_Terjual'],width=0.2)
axs[0, 1].set_title(label="Distribusi beras (2019)",fontdict={"fontsize":25})
axs[0, 1].grid(True)
axs[1, 0].bar(x=beras2020b.index,height=beras2020b['Kuantum_Terjual'],width=0.2)
axs[1, 0].set_title(label="Distribusi beras (2020)",fontdict={"fontsize":25})
axs[1, 0].grid(True)
axs[1, 1].bar(x=beras2021b.index,height=beras2021b['Kuantum_Terjual'],width=0.2)
axs[1, 1].set_title(label="Distribusi beras (2021)",fontdict={"fontsize":25})
axs[1, 1].grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##MERK BERAS DALAM SATU TAHUN (PIE CHART)

# %%
labels = []
sizes = []
keterangan_legend = []
for i in nama_beras2020[0:7].index :
  labels.append(i)
for j in nama_beras2020[0:7].Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")

fig1, ax1 = plt.subplots()
ax1.pie(sizes,
        startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title(label="Merk Al-Hambra(2020)",fontdict={"fontsize":25})
plt.legend(keterangan_legend,loc="best")
plt.show()

# %%
labels = []
sizes = []
keterangan_legend = []
for i in nama_beras2021[0:7].index :
  labels.append(i)
for j in nama_beras2021[0:7].Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
fig1, ax1 = plt.subplots()
ax1.pie(sizes,
        startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title(label="Merk Al-Hambra(2021)",fontdict={"fontsize":25})
plt.legend(keterangan_legend,loc="best")
plt.show()

# %%
nama_beras2018 = e.groupby(by="Merk_Komoditi").sum()
labels = []
sizes = []
keterangan_legend = []
for i in nama_beras2018.index :
  labels.append(i)
for j in nama_beras2018.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")

fig, axs = plt.subplots(2, 2)
axs[0, 0].pie(sizes,startangle=90)
axs[0, 0].axis("equal")
axs[0, 0].set_title(label="Merk Beras (2018)",fontdict={"fontsize":25})
axs[0, 0].legend(keterangan_legend,loc="best")
nama_beras2019 = f.groupby(by="Merk_Komoditi").sum()
zzz = nama_beras2019.rename(index={"BERAS K0MERSIL KHUSUS":"BERAS KOMERSIL KHUSUS","Beras Kita Premium":"BERAS KITA PREMIUM"})
nama_beras2019=zzz.groupby(by="Merk_Komoditi").sum()
labels = []
sizes = []
keterangan_legend = []
for i in nama_beras2019.index:
  labels.append(i)
for j in nama_beras2019.Kuantum_Terjual:
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[0, 1].pie(sizes,startangle=90)
axs[0, 1].axis("equal")
axs[0, 1].set_title(label="Merk Beras (2019)",fontdict={"fontsize":25})
axs[0, 1].legend(keterangan_legend,loc="best")
al_hambra2020= sum(nama_beras2020[0:7].Kuantum_Terjual)
labels = ["Beras Al-Hambra"]
sizes = [al_hambra2020]
keterangan_legend = []
for i in nama_beras2020[7:17].index :
  labels.append(i)
for j in nama_beras2020[7:17].Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[1, 0].pie(sizes,startangle=90)
axs[1, 0].axis("equal")
axs[1, 0].set_title(label="Merk Beras (2020)",fontdict={"fontsize":25})
axs[1, 0].legend(keterangan_legend,loc="best")
al_hambra2021= sum(nama_beras2021[0:7].Kuantum_Terjual)
labels = ["Beras Al-Hambra"]
sizes = [al_hambra2021]
keterangan_legend = []
for i in nama_beras2021[7:14].index :
  labels.append(i)
for j in nama_beras2021[7:14].Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[1, 1].pie(sizes,startangle=90)
axs[1, 1].axis("equal")
axs[1, 1].set_title(label="Merk Beras (2021)",fontdict={"fontsize":25})
axs[1, 1].legend(keterangan_legend,loc="best")
plt.show()

# %%
nama_beras2021
# Out:
#                                      No  Kemasan  ...  Koli_Terjual  Kuantum_Terjual
# Merk_Komoditi                                     ...
# Al-Hambra (Briyani)               10705   3500.0  ...            21            7.350
# Al-Hambra (Bukhori)                5227   2450.0  ...            26            9.100
# Al-Hambra (Kabsah)                13469   3500.0  ...            26            9.100
# Al-Hambra (Kebuli)                13531   5250.0  ...            25            8.750
# Al-Hambra (Mandhi)                21725   4900.0  ...            24            8.400
# Al-Hambra (Nasgor Kambing)        16336   3685.0  ...            35           11.725
# Al-Hambra (Nasgor Mesir)            799   1005.0  ...            35           11.725
# BERAS AROMA WANGI KARANGPANDAN    23579    135.0  ...           200         1000.000
# BERAS FORTIVIT                   340052    120.0  ...           932          932.000
# ...

# %% [markdown]
# #Merk Gula

# %%
gula2018 = df2018.loc[df2018.Nama_Komoditi == "GULA"].groupby(by="Merk_Komoditi").sum()
gula2019 = df2019.loc[df2019.Nama_Komoditi == "GULA"].groupby(by="Merk_Komoditi").sum()
gula2020 = df2020.loc[df2020.Nama_Komoditi == "GULA"].groupby(by="Merk_Komoditi").sum()
gula2021 = df2021.loc[df2021.Nama_Komoditi == "GULA"].groupby(by="Merk_Komoditi").sum()
gula2021
# Out:
#                     No  Kemasan  ...  Koli_Terjual  Kuantum_Terjual
# Merk_Komoditi                    ...
# GENDHIS          25593     10.0  ...           100          30000.0
# GULA POLOS      165032   5059.0  ...          1431          16688.0
# MANIS KITA     1466369    722.0  ...        133920         189078.0
#
# [3 rows x 6 columns]

# %%
labels = []
sizes = []
keterangan_legend = []
for i in gula2018.index :
  labels.append(i)
for j in gula2018.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
fig, axs = plt.subplots(2, 2)
axs[0, 0].pie(sizes,startangle=90)
axs[0, 0].axis("equal")
axs[0, 0].set_title(label="Merk Gula (2018)",fontdict={"fontsize":25})
axs[0, 0].legend(keterangan_legend,loc="best")
labels = []
sizes = []
keterangan_legend = []
for i in gula2019.index :
  labels.append(i)
for j in gula2019.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[0, 1].pie(sizes,startangle=90)
axs[0, 1].axis("equal")
axs[0, 1].set_title(label="Merk Gula (2019)",fontdict={"fontsize":25})
axs[0, 1].legend(keterangan_legend,loc="best")
labels = []
sizes = []
keterangan_legend = []
for i in gula2020.index :
  labels.append(i)
for j in gula2020.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[1, 0].pie(sizes,startangle=90)
axs[1, 0].axis("equal")
axs[1, 0].set_title(label="Merk Gula (2020)",fontdict={"fontsize":25})
axs[1, 0].legend(keterangan_legend,loc="best")
labels = []
sizes = []
keterangan_legend = []
for i in gula2021.index :
  labels.append(i)
for j in gula2021.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[1, 1].pie(sizes,startangle=90)
axs[1, 1].axis("equal")
axs[1, 1].set_title(label="Merk Gula (2021)",fontdict={"fontsize":25})
axs[1, 1].legend(keterangan_legend,loc="best")
plt.show()

# %%
guka2018 = df2018.loc[df2018.Nama_Komoditi == "MINYAK GORENG"].groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
guka2019 = df2019.loc[df2019.Nama_Komoditi == "MINYAK GORENG"].groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
guka2020 = df2020.loc[df2020.Nama_Komoditi == "MINYAK GORENG"].groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
guka2021 = df2021.loc[df2021.Nama_Komoditi == "MINYAK GORENG"].groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
fig, axs = plt.subplots(2, 2)
axs[0,0].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[0,1].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[1,0].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[1,1].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[0, 0].bar(x=guka2018.index,height=guka2018['Kuantum_Terjual'],width=0.2)
axs[0, 0].set_title(label="Distribusi MINYAK GORENG (2018)",fontdict={"fontsize":25})
axs[0, 0].grid(True)
axs[0, 1].bar(x=guka2019.index,height=guka2019['Kuantum_Terjual'],width=0.2)
axs[0, 1].set_title(label="Distribusi MINYAK GORENG (2019)",fontdict={"fontsize":25})
axs[0, 1].grid(True)
axs[1, 0].bar(x=guka2020.index,height=guka2020['Kuantum_Terjual'],width=0.2)
axs[1, 0].set_title(label="Distribusi MINYAK GORENG (2020)",fontdict={"fontsize":25})
axs[1, 0].grid(True)
axs[1, 1].bar(x=guka2021.index,height=guka2021['Kuantum_Terjual'],width=0.2)
axs[1, 1].set_title(label="Distribusi MINYAK GORENG (2021)",fontdict={"fontsize":25})
axs[1, 1].grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # MINYAK GORENG

# %%
minyak2018 = df2018.loc[df2018.Nama_Komoditi == "MINYAK GORENG"].groupby(by="Merk_Komoditi").sum()
minyak2019 = df2019.loc[df2019.Nama_Komoditi == "MINYAK GORENG"].groupby(by="Merk_Komoditi").sum()
minyak2020 = df2020.loc[df2020.Nama_Komoditi == "MINYAK GORENG"].groupby(by="Merk_Komoditi").sum()
minyak2021 = df2021.loc[df2021.Nama_Komoditi == "MINYAK GORENG"].groupby(by="Merk_Komoditi").sum()
minyak2021
# Out:
#                         No  Kemasan  ...  Koli_Terjual  Kuantum_Terjual
# Merk_Komoditi                        ...
# MINYAK GORENG KITA  873385    543.0  ...         41485          59932.0
# SOVIA                 4928      2.0  ...             8           1008.0
# TROPICAL             31381     12.0  ...             0          26000.0
#
# [3 rows x 6 columns]

# %%
labels = []
sizes = []
keterangan_legend = []
for i in minyak2018.index :
  labels.append(i)
for j in minyak2018.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
fig, axs = plt.subplots(2, 2)
axs[0, 0].pie(sizes,startangle=90)
axs[0, 0].axis("equal")
axs[0, 0].set_title(label="Merk Minyak (2018)",fontdict={"fontsize":25})
axs[0, 0].legend(keterangan_legend,loc="best")
labels = []
sizes = []
keterangan_legend = []
for i in minyak2019.index :
  labels.append(i)
for j in minyak2019.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[0, 1].pie(sizes,startangle=90)
axs[0, 1].axis("equal")
axs[0, 1].set_title(label="Merk Minyak (2019)",fontdict={"fontsize":25})
axs[0, 1].legend(keterangan_legend,loc="best")
labels = []
sizes = []
keterangan_legend = []
for i in minyak2020.index :
  labels.append(i)
for j in minyak2020.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[1, 0].pie(sizes,startangle=90)
axs[1, 0].axis("equal")
axs[1, 0].set_title(label="Merk Minyak (2020)",fontdict={"fontsize":25})
axs[1, 0].legend(keterangan_legend,loc="best")
labels = []
sizes = []
keterangan_legend = []
for i in minyak2021.index :
  labels.append(i)
for j in minyak2021.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[1, 1].pie(sizes,startangle=90)
axs[1, 1].axis("equal")
axs[1, 1].set_title(label="Merk Minyak (2021)",fontdict={"fontsize":25})
axs[1, 1].legend(keterangan_legend,loc="best")
plt.show()

# %% [markdown]
# # Komoditi Telur

# %%
lenlin=[df2018.loc[df2018.Nama_Komoditi == "TELUR"],df2019.loc[df2019.Nama_Komoditi == "TELUR"],df2020.loc[df2020.Nama_Komoditi == "TELUR"],df2021.loc[df2021.Nama_Komoditi == "TELUR"]]
z = 2018
for i in lenlin: 
  ax = i.groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"]).dropna()
  ax = ax["Kuantum_Terjual"]
  plt.plot(ax.index,ax)
  plt.rcParams['figure.figsize'] = (20, 10)
  plt.grid(True)
  plt.xlabel("Bulan",fontdict={"fontsize":15})
  plt.ylabel("Kuantum Terjual (Kg)",fontdict={"fontsize":15})
  plt.title("Distribusi Telur "+"("+str(z)+")",fontdict={"fontsize":15})
  z+=1
  plt.show()

# %% [markdown]
# # Komoditi Tepung Terigu

# %%
lenln=[df2018.loc[df2018.Nama_Komoditi == "TEPUNG TERIGU"],df2019.loc[df2019.Nama_Komoditi == "TEPUNG TERIGU"],df2020.loc[df2020.Nama_Komoditi == "TEPUNG TERIGU"],df2021.loc[df2021.Nama_Komoditi == "TEPUNG TERIGU"]]
z = 2018
for i in lenln: 
  ax = i.groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"]).dropna()
  ax = ax["Kuantum_Terjual"]
  plt.plot(ax.index,ax)
  plt.rcParams['figure.figsize'] = (20, 10)
  plt.grid(True)
  plt.xlabel("Bulan",fontdict={"fontsize":15})
  plt.ylabel("Kuantum Terjual (Kg)",fontdict={"fontsize":15})
  plt.title("Distribusi Tepung Terigu "+"("+str(z)+")",fontdict={"fontsize":15})
  z+=1
  plt.show()

# %% [markdown]
# # MERK DAGING KERBAU

# %%
kerbau2018 = df2018.loc[df2018.Nama_Komoditi == "DAGING KERBAU"].groupby(by="Merk_Komoditi").sum()
kerbau2019 = df2019.loc[df2019.Nama_Komoditi == "DAGING KERBAU"].groupby(by="Merk_Komoditi").sum()
kerbau2020 = df2020.loc[df2020.Nama_Komoditi == "DAGING KERBAU"].groupby(by="Merk_Komoditi").sum()
kerbau2021 = df2021.loc[df2021.Nama_Komoditi == "DAGING KERBAU"].groupby(by="Merk_Komoditi").sum()
kerbau2021

# %%
labels = []
sizes = []
keterangan_legend = []
for i in kerbau2018.index :
  labels.append(i)
for j in kerbau2018.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
fig, axs = plt.subplots(2, 2)
axs[0, 0].pie(sizes,startangle=90)
axs[0, 0].axis("equal")
axs[0, 0].set_title(label="Merk Daging Kerbau (2018)",fontdict={"fontsize":25})
axs[0, 0].legend(keterangan_legend,loc="best")
labels = []
sizes = []
keterangan_legend = []
for i in kerbau2019.index :
  labels.append(i)
for j in kerbau2019.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[0, 1].pie(sizes,startangle=90)
axs[0, 1].axis("equal")
axs[0, 1].set_title(label="Merk Daging Kerbau (2019)",fontdict={"fontsize":25})
axs[0, 1].legend(keterangan_legend,loc="best")
labels = []
sizes = []
keterangan_legend = []
for i in kerbau2020.index :
  labels.append(i)
for j in kerbau2020.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[1, 0].pie(sizes,startangle=90)
axs[1, 0].axis("equal")
axs[1, 0].set_title(label="Merk Daging Kerbau (2020)",fontdict={"fontsize":25})
axs[1, 0].legend(keterangan_legend,loc="best")
labels = []
sizes = []
keterangan_legend = []
for i in kerbau2021.index :
  labels.append(i)
for j in kerbau2021.Kuantum_Terjual :
  sizes.append(j)
for k in range(len(labels)):
  persentase = round(sizes[k]*100/sum(sizes),2)
  keterangan_legend.append(str(labels[k])+" "+"("+str(persentase)+"%)")
axs[1, 1].pie(sizes,startangle=90)
axs[1, 1].axis("equal")
axs[1, 1].set_title(label="Merk Daging Kerbau (2021)",fontdict={"fontsize":25})
axs[1, 1].legend(keterangan_legend,loc="best")
plt.show()

# %%
kerbau2018b = df2018.loc[df2018.Nama_Komoditi == "DAGING KERBAU"].groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
kerbau2019b = df2019.loc[df2019.Nama_Komoditi == "DAGING KERBAU"].groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
kerbau2020b = df2020.loc[df2020.Nama_Komoditi == "DAGING KERBAU"].groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
kerbau2021b = df2021.loc[df2021.Nama_Komoditi == "DAGING KERBAU"].groupby(by="Bulan").sum().reindex(["January","February","March","April","May","June","July","August","September","October","November","December"])
fig, axs = plt.subplots(2, 2)
axs[0,0].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[0,1].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[1,0].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[1,1].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[0, 0].bar(x=kerbau2018b.index,height=kerbau2018b['Kuantum_Terjual'],width=0.2)
axs[0, 0].set_title(label="Distribusi Daging Kerbau (2018)",fontdict={"fontsize":25})
axs[0, 0].grid(True)
axs[0, 1].bar(x=kerbau2019b.index,height=kerbau2019b['Kuantum_Terjual'],width=0.2)
axs[0, 1].set_title(label="Distribusi Daging Kerbau (2019)",fontdict={"fontsize":25})
axs[0, 1].grid(True)
axs[1, 0].bar(x=kerbau2020b.index,height=kerbau2020b['Kuantum_Terjual'],width=0.2)
axs[1, 0].set_title(label="Distribusi Daging Kerbau (2020)",fontdict={"fontsize":25})
axs[1, 0].grid(True)
axs[1, 1].bar(x=kerbau2021b.index,height=kerbau2021b['Kuantum_Terjual'],width=0.2)
axs[1, 1].set_title(label="Distribusi Daging Kerbau (2021)",fontdict={"fontsize":25})
axs[1, 1].grid(True)
plt.tight_layout()
plt.show()

# %%
df2020["Nama_Komoditi"].unique
# Out:
# array(['BERAS', 'MINYAK GORENG', 'TEPUNG TERIGU', 'DAGING KERBAU',
#        'TELUR', 'PAKET KOM', 'KACANG KOM DN', 'GULA', 'BAWANG MERAH',
#        'DAGING AYAM', 'SAYUR DAN BUAH KOM DN', 'BAWANG PUTIH',
#        'DAGING SAPI'], dtype=object)

# %%
paket2020 = df2020.loc[df2020.Nama_Komoditi == "PAKET KOM"]
paket2020
# Out:
#         No    Tanggal    Saluran  ... Kuantum_Terjual      Bulan       Hari
# 356    357 2020-02-07        RPK  ...           264.0   February     Friday
# 357    358 2020-02-07        RPK  ...           132.0   February     Friday
# 358    359 2020-02-07        RPK  ...           322.0   February     Friday
# 359    360 2020-02-07        RPK  ...           161.0   February     Friday
# 360    361 2020-02-07        RPK  ...           322.0   February     Friday
# ...    ...        ...        ...  ...             ...        ...        ...
# 6132  6133 2020-09-24  BUMN/BUMD  ...          1638.0  September   Thursday
# 6134  6135 2020-09-24  BUMN/BUMD  ...           819.0  September   Thursday
# 7315  7316 2020-12-23  BUMN/BUMD  ...           600.0   December  Wednesday
# 7316  7317 2020-12-23  BUMN/BUMD  ...          4800.0   December  Wednesday
# 7317  7318 2020-12-23  BUMN/BUMD  ...           600.0   December  Wednesday
#
# [332 rows x 16 columns]

# %%
paket2020.groupby(by="Merk_Komoditi").sum()
# Out:
#                                No  Kemasan  ...  Koli_Terjual  Kuantum_Terjual
# Merk_Komoditi                               ...
# BISKUIT NABATI               1847      1.0  ...           546            546.0
# BUAH SAYUR DN              448174    165.0  ...         40522          40522.0
# GARAM CAP SEGITIGA           5778   1000.0  ...          1000            500.0
# INDOMILK                    28851      5.0  ...          2134           2134.0
# KACANG HIJAU DN             32176     68.0  ...         11195          11195.0
# KACANG TANAH DN              8904     17.0  ...          1000           1000.0
# KURMA KOM                    1846    500.0  ...           274            137.0
# MARGARIN FORVITA           223378     53.0  ...          6168           6168.0
# MIE SEDAAP                   7317      1.0  ...          4800           4800.0
# SARDEN ABC 155 GR            1523      1.0  ...           304            304.0
# ...

# %%
plt.bar(x=paket2020.groupby(by="Merk_Komoditi").sum().index,height=paket2020.groupby(by="Merk_Komoditi").sum()["Kuantum_Terjual"])
plt.grid(True)
plt.rcParams['figure.figsize'] = (30, 10)
plt.tight_layout()
plt.title("Paket Kom (2020)",fontdict={"fontsize":25})
plt.ylabel("Kuantum Terjual (Kg)",fontdict={"fontsize":25})
plt.show()

# %%
paket2021 = df2021.loc[df2021.Nama_Komoditi == "PAKET KOM"]
plt.bar(x=paket2021.groupby(by="Merk_Komoditi").sum().index,height=paket2021.groupby(by="Merk_Komoditi").sum()["Kuantum_Terjual"])
plt.grid(True)
plt.rcParams['figure.figsize'] = (40, 10)
plt.tight_layout()
plt.title("Paket Kom (2021)",fontdict={"fontsize":25})
plt.ylabel("Kuantum Terjual (Kg)",fontdict={"fontsize":25})
plt.show()

# %%
df2018total = df2018.groupby(by="Nama_Komoditi").sum()
df2019total = df2019.groupby(by="Nama_Komoditi").sum()
df2020total = df2020.groupby(by="Nama_Komoditi").sum()
df2021total = df2021.groupby(by="Nama_Komoditi").sum()
fig, axs = plt.subplots(2, 2)
axs[0,0].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[0,1].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[1,0].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[1,1].set_ylabel(ylabel = "Kuantum Terjual (Kg)",fontdict={"fontsize":15})
axs[0, 0].bar(x=df2018total.index,height=df2018total['Kuantum_Terjual'],width=0.2)
axs[0, 0].set_title(label="Komoditas (2018)",fontdict={"fontsize":25})
axs[0, 0].grid(True)
axs[0, 1].bar(x=df2019total.index,height=df2019total['Kuantum_Terjual'],width=0.2)
axs[0, 1].set_title(label="Komoditas (2019)",fontdict={"fontsize":25})
axs[0, 1].grid(True)
axs[1, 0].bar(x=df2020total.index,height=df2020total['Kuantum_Terjual'],width=0.2)
axs[1, 0].set_title(label="Distribusi beras (2020)",fontdict={"fontsize":25})
axs[1, 0].grid(True)
axs[1, 1].bar(x=df2021total.index,height=df2021total['Kuantum_Terjual'],width=0.2)
axs[1, 1].set_title(label="Distribusi beras (2021)",fontdict={"fontsize":25})
axs[1, 1].grid(True)
plt.tight_layout()
plt.show()

# %%
df2020total
# Out:
#                             No   Kemasan  ...  Koli_Terjual  Kuantum_Terjual
# Nama_Komoditi                             ...
# BAWANG MERAH            510111     53.55  ...         22092         10670.10
# BAWANG PUTIH           1417250    148.00  ...         76189         40314.00
# BERAS                  7044972  36422.95  ...        490593       5022967.25
# DAGING AYAM             258100     30.50  ...         17898          9588.00
# DAGING KERBAU            95761     96.00  ...           760          1013.00
# DAGING SAPI             404706     58.00  ...           402           402.00
# GULA                   7245445  59064.00  ...        212960        862553.00
# KACANG KOM DN          1010009    149.00  ...         92464         46232.00
# MINYAK GORENG          2392930   2175.00  ...        220151        265529.00
# PAKET KOM               833637   1829.00  ...         93371         92734.00
# SAYUR DAN BUAH KOM DN   894430    158.50  ...         48282         44539.00
# ...
